# %%
import numpy as np

def G(x, s ,m):
  p1 = 1/(np.sqrt(2*3.14)*s)
  p2 = 2.17**(-((x-m)**2))
  return p1*p2

d = [2,25,100,152,1,10,15,2,22,35,41,27,25,21]
x1 = 30
x2 = 50

m = np.mean(d)
s = np.var(d)

if G(x1, s, m) > G(x2, s, m):
  print(x1)
else:
  print(x2)
# Out:
# 30
